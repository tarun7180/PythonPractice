# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.chdir("E:\Tarun\PythonBlogsExcel")

# %%
carsData = pd.read_csv('Toyota.csv', index_col=0, na_values=["??","???"])

# %%
carsData2 = carsData.copy()

# %%
carsData2.dropna(axis = 0, inplace=True)

# %%
#Scatter diagram
plt.scatter(carsData2['Age'], carsData2['Price'], c='red')

# %%
#Histogram
plt.hist(carsData2['KM'],
        color = 'green',
        edgecolor = 'white',
        bins = 5)
plt.title('Histogram of Kilometer')
plt.xlabel('Kilometer')
plt.ylabel('Frequency')
plt.show()

# %%
#Bar plot
counts = [979,120,12]
fuelType = ('Petrol','Diesel','CNG')
index = np.arange(len(fuelType))
plt.bar(index, counts, color=['red','blue','cyan'])
plt.title('Bar plot of fuel types')
plt.xlabel('Fuel Types')
plt.ylabel('Frquency')
plt.show()
